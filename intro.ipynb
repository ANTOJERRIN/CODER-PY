# %% [markdown]
# what is coding??
# it is the conservation which we talk usually but to machines in their lang like machine level langauge. like what we program(c/python ) is getting converted to 0001100.

# %% [markdown]
# python??
# --interpreted lang
# like see like someone who is giving speech in the mixed audiences like fifa worldcup ceremony a person it there who will translate the gven speech into respective languages.. means line by line it complies the code but complier in c/c++-->is like whole program gets complied at once but python takes time for execution.
# --dynamically typed means like how we wear clothes to go college but in py autmatically pyhton understands what data which we give like c/c++ we have to show what data we re writing(statically typed
# )

# %% [markdown]
# oops:
# c-->procedure (modular programming)
# template is taken like class from that we can create many products(objects) out from that

# %%
#first code
print("Hello world")
print("namsakra")
# Out:
# Hello world
# namsakra
