# %%
num1=int(input("enter the number"))
num2=int(input("enter the number2"))
e=num1**num2
print(f"exponential is {num1} ** {num2}={e}")
# Out:
# enter the number 2
# enter the number2 2
# exponential is 2 ** 2=4

# %%
grade=23
if grade>20:
    print("best")
elif grade<20:
    print("improvemnt")
# Out:
# best

# %%
def add(n):
    a=n+n
    print(a)
add(4)
# Out:
# 8
