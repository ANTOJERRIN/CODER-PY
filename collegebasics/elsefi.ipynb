# %% [markdown]
# elif uis use dwhen u have more numbe r of choices or alternatives

# %%
marks=float(input("enter your marks:"))
if(marks>=47):
    print("you are pass")
else:
    print("your are fail")
# Out:
# your are fail

# %%
name=input("enter your team:")
np=input("enter the player name:")
if(name=="RCB"):
    if(np=="VIRAT KOHLI"):
        print("21 crores")
else:
    if(name=="SRH"):
        if(np=="ishan"):
            print("10 crores")

# %%
#1.wa py to conduct a quiz foe students
print("welcome to my quix")
# Out:
# welcome to my quix

# %%
#looping constructs
"""while condition:
        statement1
        statement2
        """
#wa py to print natural numbers from 1 to n
n=int(input("enter the value:"))
for i in range(1,n+1):
    print(i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 7
#       2 """while condition:
#       3         statement1
#       4         statement2
#       5         """
#       6 #wa py to print natural numbers from 1 to n
# ----> 7 n=int(input("enter the value:"))
#       8 for i in range(1,n+1):
#       9     print(i)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
#wapy to print odd natural numbers from 1 to n:
n=int(input("enter the vlaue:"))
while i<=n:
    if(i%2!=0):
        print(i)
        i+=1

# %%
#wa py to do check whther the give number is palindrome or not
n
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #wa py to do check whther the give number is palindrome or not
# ----> 2 n
#
# NameError: name 'n' is not defined
