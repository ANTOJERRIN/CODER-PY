# %%
import numpy as np
array1=np.array([[10,20],[12,13]])
print(array1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#       2 array1=np.array([[10,20],[12,13]])
#       3 print(array1)
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# types of nd arrays:
# 1.0d array:
#  import numpy as np
#  array1 = np.array()
