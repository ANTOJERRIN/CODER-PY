# %% [markdown]
# fileobject= open(filename,accessmode)
#
# read-> r
# write->w
# append->a
# r+->read and otherwise write or append
# w+fine
# read()->it will help u to read starting from first charatcer tot he last charcacter and whatbever it is reading wioll be convetrted to string
#
# readline()->
# readlines()
# file positioning functions:
# tell()->it will tell to find the correct file pointer location like cursor
# seek()->inorder to move the cursor form one place to another
# seek(offset,from)
