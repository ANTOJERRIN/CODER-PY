# %%
#wapy to find square of given positive number using user defined function
def sq(n):
    if(n>=0):
        result=n*n
        print("the square of the number is",result)
    else:
        print("please enter a positive number")
sq(-5)
# Out:
# please enter a positive number

# %% [markdown]
# functions is a reusbale block of code
