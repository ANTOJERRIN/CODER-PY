# %%
S={"banana","apple","orange"}
print(s)
s.add("watermelon")
print(s)
s.pop("orange")
print(s)
s.remove("apple")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 S={"banana","apple","orange"}
# ----> 2 print(s)
#       3 s.add("watermelon")
#       4 print(s)
#
# NameError: name 's' is not defined

# %%
#write a py program to create a empty list and add atleast 5 elements one after the other .add two more elements into the list print the index value of a particular element
l=[]
for i in range(5):
    e=input("enter the element :")
    l.append(e)
print(l)
for i in range(2):
    e=input("enter the elemnt")
    l.append(e)
print(l)
e=input("enter the element tpo fins the index value:")
if e in l:
    print("index value of",e,"is",l.index(e))
# Out:
# ['jerrin', 'anto', 'shreya', 'karen', 'chruistiuna']
# ['jerrin', 'anto', 'shreya', 'karen', 'chruistiuna', 'jk', 'gh']
# index valueof karen is 3

# %%
#write a py program to create a empty list and add atleast 5 elements one after the other .add two more elements into the list print the index value of a particular element
l=[]
[l.append(input("enter the elemnt:")) for i in range(5)]
print(l)
[l.append(input("enter the element:")) for i in range(2)]
print(l)
e=input("enter the lement to be searched :")\
if e in l:
    print("index value of ",e,"is",l.index(e))
# Out:
#   Cell In[1], line 8
#     if e in l:
#              ^
# SyntaxError: invalid syntax

# %%
d={"name":"john","age":30,"city":"new york"}
print(d)
d["age"]=45
print(d)
d["country"]="pakistan"
print(d)
d["name"]="anthony joshua"
print(d)
for i,a in d.items():
    print(i,"=",a)
# Out:
# {'name': 'john', 'age': 30, 'city': 'new york'}
# {'name': 'john', 'age': 45, 'city': 'new york'}
# {'name': 'john', 'age': 45, 'city': 'new york', 'country': 'pakistan'}
# {'name': 'anthony joshua', 'age': 45, 'city': 'new york', 'country': 'pakistan'}
# name = anthony joshua
# age = 45
# city = new york
# country = pakistan

# %%
"""add one list to the end of another list ..copy one list content to the another..sort the elemnts of list 
...count no of occurrence of the particular value.combine the elements of set1 and set2 .print the elemeents of set1 which is not 
set2.print the elements which are common in both sets.add new element into the dictionary"""
