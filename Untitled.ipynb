# %%
tup=('a','b','c')
print(tup)
# Out:
# ('a', 'b', 'c')

# %%
import numpy as n
a=n.array([1,2,3])
b=n.array([2,3,4])
print(a+b)
print(a-b)
# Out:
# [3 5 7]
# [-1 -1 -1]

# %%
c=n.array([[1,2,3]])
d=n.array([[4,5,6]])
print(c*d)
# Out:
# [[ 4 10 18]]

# %%
print(max(c))
# Out:
# [1 2 3]
