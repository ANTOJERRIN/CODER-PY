# %%
1+1
1+1
# Out:
# 2

# %%
## case senisitivity of python
name="k"
Name="g"
print(name)
print(Name)
# Out:
# k
# g

# %%
## indentation
age=32
if age>36:
    print(age)
else:
    print("your a fool")
# Out:
# your a fool

# %%
##TYEPE INFERENCE
v=0.6;
print(type(v))
v="k"
print(type(v))
# Out:
# <class 'float'>
# <class 'str'>

# %%
## variables
##declaring and assigning variables
a=32
h=6.1
name="k"
is_st=True
#printing values
print("age:",a)
print("height:",h)
print("name:",name)
# Out:
# age: 32
# height: 6.1
# name: k

# %%
a=10
b=5
add=a+b
s=a-b
m=a%b
d=a/b
e=a//b ## we are doing floor division-the decimal point will be removed 
print(add)
print(s)
print(m)
print(d)
print(e)
# Out:
# 15
# 5
# 0
# 2.0
# 2

# %%
## comparision operators
## ==
a=10
b=10
r=(a==b)
a==b
# Out:
# True

# %%
s="krish"
s1="krish"
s==s1
# Out:
# True

# %%
## !=
s!=s1
# Out:
# False

# %%
s5="krish"
s7="Krish"
s5!=s7
# Out:
# True

# %%
## >
a=45
b=20
a>b
# Out:
# True

# %%
print(a<b)
# Out:
# False

# %%
n1=int(input("number enter "))
n2=45
print(n1>=n2)
# Out:
# False

# %%
##logical operators
X=True
Y=True
print( X and Y )
w= False
c=True
print( w or c)
v=False
print ( not v)
# Out:
# True
# True
# True

# %%
## Simple calculator
a=int(input("enter the n1:"))
b=int(input("enter the n2:"))
A=a+b
s=a-b
m=a*b
ex=a**b
mo=a%b
d=a/b
fd=a//b

print("add:",A)
print("add:",s)
print("add:",m)
print("add:",ex)
print("add:",mo)
print("add:",d)
print("add:",fd)
# Out:
# add: 6
# add: -2
# add: 8
# add: 16
# add: 2
# add: 0.5
# add: 0
