# %% [markdown]
# understanding the print() function is that we re printing the statement to the complier inrder we re telling it to print that in the output....screen

# %% [markdown]
# now the follwoing snippet code is as below:

# %%
age=20
name="nitin"
s=200
print(str(s)+str(age)+name)
# Out:
# 20020nitin

# %%
#dynamic typing
"""the thing is here we re about tot say that pyhton does take the inputs from the user thet type of data and the user doesnt need to worry about that"""

# %%
#strings and indexing
#strings are immutable
n="python"
print(n[0])
print(n[-1])
# Out:
# p
# n

# %%
d = ['jerru', 'goo', 34, 45]
d.append('hola')
print(d)

print(d.pop())
print(d)

d[3] = 78
print(d)

d.append("spain")
print(d)

print(len(d))

f = []
f = d.copy()
print(f)
print(dir(f))

print(d)

x=(34,5,7,9)
print(dir(x))
print(x*3)
print(x.count(5))
# Out:
# ['jerru', 'goo', 34, 45, 'hola']
# hola
# ['jerru', 'goo', 34, 45]
# ['jerru', 'goo', 34, 78]
# ['jerru', 'goo', 34, 78, 'spain']
# 5
# ['jerru', 'goo', 34, 78, 'spain']
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']
# ['jerru', 'goo', 34, 78, 'spain']
# ...

# %%
#sets 
x={2,4,5,9,8}
print(x.add(34))
print(x.remove(4))
print(x)
print(dir(x))
d={1,2,3,4}
f={3,4,5,6}
print(d|f)
print(d&f)
# Out:
# None
# None
# {2, 34, 5, 8, 9}
# ['__and__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__iand__', '__init__', '__init_subclass__', '__ior__', '__isub__', '__iter__', '__ixor__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__rand__', '__reduce__', '__reduce_ex__', '__repr__', '__ror__', '__rsub__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__xor__', 'add', 'clear', 'copy', 'difference', 'difference_update', 'discard', 'intersection', 'intersection_update', 'isdisjoint', 'issubset', 'issuperset', 'pop', 'remove', 'symmetric_difference', 'symmetric_difference_update', 'union', 'update']
# {1, 2, 3, 4, 5, 6}
# {3, 4}

# %% [markdown]
# so here if we want to do union and intersection of the sets then we use |-union and intersection-&
# and one more thing is pop() in lists gives ouput of the lastelement and pop() in sets will give u random element present in the sets

# %%
n=input("")
r=list(map(int,n.split()))
print(d)
# Out:
# ['1234']

# %%
def lg():
    n=int(input(""))
    l=list(map(int,input().split()))
    f=l[0]
    s=l[0]
    for i in range(i,n):
        if l[i]>f:
            return l[i]
        elif l[i]<s:
            return l[i]
lg()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[31], line 11
#       9         elif l[i]<s:
#      10             return l[i]
# ---> 11 lg()
#
# Cell In[31], line 6, in lg()
#       4 f=l[0]
#       5 s=l[0]
# ----> 6 for i in range(i,n):
#       7     if l[i]>f:
#       8         return l[i]
#
# UnboundLocalError: cannot access local variable 'i' where it is not associated with a value
