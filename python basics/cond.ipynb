# %%
## conditional statements
a=int(input("enter the age:"))
if a>=20:
    print("ur allowed vote")
else:
    print("im a kid ")
# Out:
# im a kid

# %%
## else block will execute only if the if block is false
a=16
if a>=18:
    print("elgible")
else:
    print("not elgible")
# Out:
# not elgible

# %%
#elif statememnt 
a=int(input("input age:"))
if a>=18:
    print("eligible for voting")
elif a<18:
    print("ur a teenager")
else:
    print("ur a baby")
# Out:
# ur a teenager

# %%
#nested cond
n=int(input("ente rthe n1:" ))
if n>=0:
    print("number is pos")
    if(n%2==0):
        print("even")
    else:
        print("odd")
else:
    print("no is negative")
# Out:
# number is pos
# even

# %%
## practicla example-1
##determine year is leap year
y=int(input("enter the year which ur aere currently living in this world:"))
if y%4==0:
    if(y%100==0):
        if(y%400==0):
            print(y,"is the leap year")
else:
    print(y,"is the leap year")
# Out:
# 2010 is the leap year

# %%
d=int(input("enter the amt u have "))
if(d<150):
    print("u can go to dude movie with this money",d)
elif(d>150 and d<=300):
    print(d,"with this money u can go to avatar fire and ash but u cant buy snacks at all in pvr")
else:
    print("dont go to theatre only just sleep")
# Out:
# 290 with this money u can go to avatar fire and ash but u cant buy snacks at all in pvr

# %%
#internship day-1 work problems
name = input("Enter your name: ")       # Gets TEXT → String type
age = int(input("Enter your age: "))    # Converts to NUMBER → Integer type
height = float(input("Enter height: ")) # Converts to DECIMAL → Float type

# type() function shows what "box type" you're using
print(type(name))    # Shows: <class 'str'>  (string box)
print(type(age))     # Shows: <class 'int'>  (integer box)
print(type(height))  # Shows: <class 'float'> (float box)
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
#internship day-1 work problems
# Instead of just:
age = input("Enter age: ")  # Risky! Could be "twenty-five"

# Do this:
try:
    age = int(input("Enter age: "))
except ValueError:
    print("Please enter a number like 25, not 'twenty-five'")
# Out:
# Please enter a number like 25, not 'twenty-five'

# %%
#internship day-2 work problems
current_salary=float(input("enter ur current salary:"))
age=int(input("enter ut age"))
average_experience = (5 + 3 + 7) / 3    # Calculate average: 5.0 years
salary_increase = current_salary * 1.1  # 10% raise
years_until_retirement = 65 - age
print(years_until_retirement)
print(average_experience)
print(salary_increase)       # Years left
skill=input("enter ur skill:")
years_experience=int(input("enter ur experience:"))
if years_experience >= 5:           # "Is experience 5 or more?"
    print("Qualifies for Senior role")

if skill == "Python":               # "Is skill exactly 'Python'?"
    print("Has required skill")
has_degree=bool(input("do u have degree reply it through true or false:"))
has_python_skill=bool(input("do u have python skill reply it through true or false:"))
has_java_skill=bool(input("do u have java skill reply it through true or false:"))

if (has_degree == True) and (years_experience >= 3):
    # BOTH must be true
    print("Qualifies for Mid-level position")

if (has_python_skill == True) or (has_java_skill == True):
    # EITHER can be true
    print("Has programming experience")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 #internship day-2 work problems
# ----> 2 current_salary=float(input("enter ur current salary:"))
#       3 age=int(input("enter ut age"))
#       4 average_experience = (5 + 3 + 7) / 3    # Calculate average: 5.0 years
#
# ValueError: could not convert string to float: ''

# %%
##internship day-2 work problems
result_1= 2 + 3 * 4  
print(result_1)    # Is it 20 or 14?
# Python calculates: 3 * 4 = 12, then + 2 = 14
# Because: Multiplication (*) before Addition (+)
num1 = float(input("Enter first number: "))    # Gets number 1
operator = input("Enter operator: ")          # Gets +, -, *, /
num2 = float(input("Enter second number: "))  # Gets number 2

# The "if-elif" chain checks WHICH operator:
if operator == "+":
    result = num1 + num2      # Addition operator
elif operator == "-":
    result = num1 - num2    
elif operator == "*":
    result=num1 * num2
elif operator == "/":  
    result=num1 / num2     
print(result)      # Subtraction operator
# ... etc
# Out:
# 14
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 6
#       3 print(result_1)    # Is it 20 or 14?
#       4 # Python calculates: 3 * 4 = 12, then + 2 = 14
#       5 # Because: Multiplication (*) before Addition (+)
# ----> 6 num1 = float(input("Enter first number: "))    # Gets number 1
#       7 operator = input("Enter operator: ")          # Gets +, -, *, /
#       8 num2 = float(input("Enter second number: "))  # Gets number 2
#
# ValueError: could not convert string to float: ''

# %%
#internhsip day-3 wokr problems
# --- IGNORE ---    
name=""
skills=["Java","Python","C++"]
print(len(skills)>0)
experince=2
has_degree=True
print(has_degree and experince>=2 and len(skills)>0)
#grade classifeier codes
score = float(input("Enter test score: "))

# This creates a DECISION PATH:
if score >= 90:          # PATH 1: Excellent scores
    grade = "A"
    message = "Excellent!"
elif score >= 80:        # PATH 2: Good scores
    grade = "B"
    message = "Good job!"
elif score >= 70:        # PATH 3: Average scores
    grade = "C"
    message = "Satisfactory"
else:                    # PATH 4: Everything else
    grade = "F"
    message = "Needs help"
print("Grade:",grade)
print(message)
#candidate resume analyiser
candidate=input("enter the candiate name or return no canddiate:")
skills1=["Java","C++","HTML"]
def check_candidate(candidate):
    if not candidate:
        return "No candidate"
    
    if not candidate.skills1:
        return "No skills"
    
    if "Python" not in candidate.skills:
        return "Missing Python"
    
    return "Qualified"
# Out:
# True
# True
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 10
#       8 print(has_degree and experince>=2 and len(skills)>0)
#       9 #grade classifeier codes
# ---> 10 score = float(input("Enter test score: "))
#      12 # This creates a DECISION PATH:
#      13 if score >= 90:          # PATH 1: Excellent scores
#
# ValueError: could not convert string to float: ''

# %%
#internship day-4 work problems
"""age=int(input(""))
has_degree=bool(input(""))
years_exp=int(input(""))
if age >= 18:                    # First: Check basic eligibility
    if has_degree:               # Second: Check education
        if years_exp >= 2:       # Third: Check experience
            print("Fully Qualified")
        else:
            print("Needs more experience")
    else:
        print("Degree required")
else:
    print("Too young")
print("fully qualified")  if (age>=18 and has_degree and years_exp>=2) else print("needs more experience")  
if years_exp >= 5:
    level = "Senior"
else:
    level = "Junior"
level= "Senior" if years_exp>=5 else "Junior"    
print(level)"""
#job qualification checker
age = int(input("Enter age: "))
years_exp = int(input("Years of experience: "))
has_degree = input("Degree? (yes/no): ").lower()#tryingto parse in lowercase characters

# This creates a HIERARCHY of checks:
if age < 18:                          # LEVEL 1: Basic age check
    result = "Too young"
elif years_exp < 2:                   # LEVEL 2: Experience check
    result = "Needs more experience"
elif has_degree == "no":              # LEVEL 3: Education check
    result = "Degree required"
else:                                 # LEVEL 4: Qualification level
    if years_exp >= 5 and has_degree == "yes":
        result = "Senior Level"       # SUB-LEVEL: Senior
    elif years_exp >= 3:
        result = "Mid Level"          # SUB-LEVEL: Mid
    else:
        result = "Junior Level"       # SUB-LEVEL: Junior
print(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 23
#       2 """age=int(input(""))
#       3 has_degree=bool(input(""))
#       4 years_exp=int(input(""))
#    (...)     20 level= "Senior" if years_exp>=5 else "Junior"
#      21 print(level)"""
#      22 #job qualification checker
# ---> 23 age = int(input("Enter age: "))
#      24 years_exp = int(input("Years of experience: "))
#      25 has_degree = input("Degree? (yes/no): ").lower()#tryingto parse in lowercase characters
#
# ValueError: invalid literal for int() with base 10: ''

# %%
candidate={'is_proper_age':25,
           'education':True,
           'experience':3,
           'skills':['Python','Java']}
def is_eligible(candidate):
    return (is_proper_age(candidate['age']) and
            has_education_or_experience(candidate) and
            has_sufficient_skills(candidate.skills))

if is_eligible(candidate):
    hire_candidate()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 10
#       5 def is_eligible(candidate):
#       6     return (is_proper_age(candidate['age']) and
#       7             has_education_or_experience(candidate) and
#       8             has_sufficient_skills(candidate.skills))
# ---> 10 if is_eligible(candidate):
#      11     hire_candidate()
#
# Cell In[13], line 6, in is_eligible(candidate)
#       5 def is_eligible(candidate):
# ----> 6     return (is_proper_age(candidate['age']) and
#       7             has_education_or_experience(candidate) and
#       8             has_sufficient_skills(candidate.skills))
#
# NameError: name 'is_proper_age' is not defined
