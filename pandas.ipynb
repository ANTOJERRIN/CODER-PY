# %%
import pandas as pd
student_data={
    "student_name":["shiva","jerrin","jay","ankush"],
    "srn":[10,20,30,40],
    "semester":[8,6,4,2],
    "CpGa":[8,9.9,9.8,9.7],
}
df=pd.DataFrame(student_data)
print(df)
data={
    "calories":[420,380,390],
    "duration":[10,20,30]
# Out:
#   student_name  srn  semester  CpGa
# 0        shiva   10         8   8.0
# 1       jerrin   20         6   9.9
# 2          jay   30         4   9.8
# 3       ankush   40         2   9.7

# %%
import pandas as pd
shop={
    "item":["macbook","imac","iphone"],
    "mrp":["90897","90876","123458"],
    "shippingfees":["234","345","5434"]
}
e=pd.DataFrame(shop)
print(e)
# Out:
#       item     mrp shippingfees
# 0  macbook   90897          234
# 1     imac   90876          345
# 2   iphone  123458         5434

# %%
import pandas  as pd
team={
    "name":["csk","rcb","kxip"],
    "location":["chennai","bangalore","punjab"],
    "purse":["54739389","36201937","9479102"],
}
w=pd.DataFrame(team)
print(w)
# Out:
#    name   location     purse
# 0   csk    chennai  54739389
# 1   rcb  bangalore  36201937
# 2  kxip     punjab   9479102
